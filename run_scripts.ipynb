# %% [markdown]
# <a href="https://colab.research.google.com/github/carversh/DL_sc/blob/main/run_scripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive', force_remount=True)

# Set the current working directory
os.chdir('/content/drive/MyDrive/AM231_project')

# !pip install tensorboardX
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python sep_laplacian_script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_1_update_lasso_0point1_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0.1
# !python sep_laplacian_script_unrolled_dl.py --conventional --init_pytorch --descr_file lapl_genes_1_update_lasso_0point1_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0.1

# !python sep_laplacian_script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_0point01_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0.01
# !python sep_laplacian_script_unrolled_dl.py --conventional --init_pytorch --descr_file lapl_genes_0point01_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0.01

# !python sep_laplacian_script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_10_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 10
# !python sep_laplacian_script_unrolled_dl.py --conventional --init_pytorch --descr_file lapl_genes_10_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 10
# Out:
# Constructing pytorch model...
# cuda:0
# 200
# lasso update 5
# name input data guide_pooled
# number of epochs 250
# milestones [100, 150, 200]
# normalize greater one True
# normalize False
# batch size 512
# lasso update period 5
# lasso lr 0.0001
# cuda:0
# processing guide_pooled...
# Loading expression matrix and indicator matrix...
# Initial Dictionary Dimensions with pytorch guide torch.Size([15668, 10])
# End processing ready for DL...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 48it [00:08,  5.45it/s]
# ...

# %%
# !python script_unrolled_dl.py --conventional --descr_file lapl_genes_0_batch_512_initial_dict_data_correct_lr --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0
# !python script_unrolled_dl.py --guide_pool --descr_file lapl_genes_0_batch_512_initial_dict_data_correct_lr --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0
# Out:
# Constructing pytorch model...
# cuda:0
# 200
# lasso update 1
# lr lasso 0.001
# name input data conventional
# number of epochs 250
# milestones [100, 150, 200]
# normalize greater one True
# normalize False
# batch size 512
# lasso update period 1
# cuda:0
# processing conventional...
# Loading expression matrix and indicator matrix...
# Initial Dictionary Dimensions torch.Size([16952, 10])
# End processing ready for DL...
# Initializing dictionary to random columns of data...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python script_unrolled_dl.py --guide_pool --descr_file lapl_genes_0_250_epochs_update_lasso_per_it_initial_dict_data --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0
# !python script_unrolled_dl.py --conventional --descr_file lapl_genes_0_250_epochs_update_lasso_per_it_batch_512_initial_dict_data --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0

# !python script_unrolled_dl.py --guide_pool --descr_file vanilla_250_epochs_update_lasso_per_it_initial_dict_data --normalize_greater_one
# !python script_unrolled_dl.py --conventional --descr_file vanilla_250_epochs_update_lasso_per_it_batch_512_initial_dict_data --normalize_greater_one
# Out:
# Constructing pytorch model...
# cuda:0
# 200
# lasso update 1
# name input data guide_pooled
# number of epochs 250
# milestones [100, 150, 200]
# normalize greater one True
# normalize False
# batch size 512
# lasso update period 1
# cuda:0
# processing guide_pooled...
# Loading expression matrix and indicator matrix...
# Initial Dictionary Dimensions torch.Size([15668, 10])
# End processing ready for DL...
# Initializing dictionary to random columns of data...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 48it [00:09,  5.25it/s]
# ...

# %%
# !python sep_laplacian_script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_0_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0
# !python sep_laplacian_script_unrolled_dl.py --conventional --init_pytorch --descr_file lapl_genes_0_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 0

# !python sep_laplacian_script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_1500_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 1500
# !python sep_laplacian_script_unrolled_dl.py --conventional --init_pytorch --descr_file lapl_genes_1500_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 1500

# !python sep_laplacian_script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_500_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 500
# !python sep_laplacian_script_unrolled_dl.py --conventional --init_pytorch --descr_file lapl_genes_500_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 500

# !python sep_laplacian_script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_100_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 100
# !python sep_laplacian_script_unrolled_dl.py --conventional --init_pytorch --descr_file lapl_genes_100_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 100
# Out:
# Constructing pytorch model...
# cuda:0
# 200
# lasso update 5
# name input data conventional
# number of epochs 250
# milestones [100, 150, 200]
# normalize greater one True
# normalize False
# batch size 512
# lasso update period 5
# lasso lr 0.0001
# cuda:0
# processing conventional...
# Loading expression matrix and indicator matrix...
# Initial Dictionary Dimensions with pytorch conven torch.Size([16952, 10])
# End processing ready for DL...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 170it [00:33,  5.05it/s]
# ...

# %%
import os
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive', force_remount=True)

# Set the current working directory
os.chdir('/content/drive/MyDrive/AM231_project')

# !pip install tensorboardX


# !python sep_laplacian_script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_1000_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 1000
# !python sep_laplacian_script_unrolled_dl.py --conventional --init_pytorch --descr_file lapl_genes_1000_update_lasso_5_init_pytorch_reduce_LR --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 1000
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 12.6 MB/s eta 0:00:00
# ...
# Constructing pytorch model...
# cuda:0
# 200
# lasso update 5
# name input data guide_pooled
# number of epochs 200
# milestones [100, 150]
# normalize greater one True
# normalize False
# batch size 512
# lasso update period 5
# cuda:0
# processing guide_pooled...
# Loading expression matrix and indicator matrix...
# Initial Dictionary Dimensions with pytorch guide torch.Size([15668, 10])
# End processing ready for DL...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# ...

# %%
# !python script_unrolled_dl.py --guide_pool --init_pytorch --descr_file lapl_genes_1000_update_lasso_5 --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 1000
# !python script_unrolled_dl.py --conventional --descr_file lapl_genes_1000_update_lasso_5 --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 1000
# Out:
# Constructing pytorch model...
# cuda:0
# 200
# lasso update 5
# name input data conventional
# number of epochs 200
# milestones [150]
# normalize greater one True
# normalize False
# batch size 512
# lasso update period 5
# cuda:0
# processing conventional...
# Loading expression matrix and indicator matrix...
# Initial Dictionary Dimensions torch.Size([16952, 10])
# End processing ready for DL...
# Initializing dictionary to random columns of data...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 170it [00:32,  5.24it/s]
# ...

# %%
# !python script_unrolled_dl.py --guide_pool --descr_file lapl_genes_100_batch_512_initial_dict_data --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 100
# !python script_unrolled_dl.py --conventional --descr_file lapl_genes_100_batch_512_initial_dict_data --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 100
# !python script_unrolled_dl.py --guide_pool --descr_file lapl_genes_500_batch_512_initial_dict_data --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 500
# !python script_unrolled_dl.py --conventional --descr_file lapl_genes_500_batch_512_initial_dict_data --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 500
# !python script_unrolled_dl.py --guide_pool --descr_file lapl_genes_300_batch_512_initial_dict_data --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 300
# !python script_unrolled_dl.py --conventional --descr_file lapl_genes_300_batch_512_initial_dict_data --normalize_greater_one --laplacian_genes --lambda_L_genes_reg 300
# Out:
# Constructing pytorch model...
# cuda:0
# 200
# name input data guide_pooled
# number of epochs 200
# milestones [150]
# normalize greater one True
# normalize False
# batch size 512
# lasso update period 20
# cuda:0
# processing guide_pooled...
# Loading expression matrix and indicator matrix...
# Initial Dictionary Dimensions torch.Size([15668, 10])
# End processing ready for DL...
# Initializing dictionary to random columns of data...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 48it [00:10,  4.77it/s]
# ...

# %%
# !python simulate_script_unrolled_dl.py --descr_file initialize_rand_dictionary_from_data --normalize_greater_one
# Out:
# Constructing pytorch model...
# 2.0.0+cu118
# cuda:0
# 200
# name input data sim
# number of epochs 200
# milestones [150]
# normalize greater one True
# normalize False
# batch size 1024
# lasso update period 1
# cuda:0
# processing sim...
# Loading expression matrix and indicator matrix...
# modules 10
# tensX torch.Size([2000, 200])
# indices tensor([ 382, 1789, 1102,  610, 1580, 1842,  886, 1057, 1699, 1754])
# Initial Dictionary Dimensions torch.Size([200, 10])
# Initializing dictionary to random columns of data...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 2it [00:00, 13.99it/s]
# initial_loss 0.9060769975185394
# Check if GPU is being used
# PASS! GPU is used for training!
# Training Network
# ...

# %%
# !python script_unrolled_dl.py --guide_pool --descr_file batch_512_initial_dict_data --normalize_greater_one
# !python script_unrolled_dl.py --conventional --descr_file batch_512_initial_dict_data --normalize_greater_one
# Out:
# Constructing pytorch model...
# cuda:0
# 200
# name input data guide_pooled
# number of epochs 200
# milestones [150]
# normalize greater one True
# normalize False
# batch size 512
# lasso update period 1
# cuda:0
# processing guide_pooled...
# Loading expression matrix and indicator matrix...
# Initial Dictionary Dimensions torch.Size([15668, 10])
# End processing ready for DL...
# Initializing dictionary to random columns of data...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 48it [00:07,  6.34it/s]
# initial_loss 1149.3870646158855
# Check if GPU is being used
# PASS! GPU is used for training!
# Training Network
# ...

# %%
# !python script_unrolled_dl.py --guide_pool
# !python script_unrolled_dl.py --conventional
# Out:
# Constructing pytorch model...
# cuda:0
# 200
#  guide_pooled
# guide_pooled_processed_exp.npy
# guide_pooled_processed_logmeanexp.npy
# GSM6858450_KD_guide_pooled_perturbations.txt
# number of epochs 100
# lasso update period 20
# cuda:0
# processing guide_pooled...
# Loading expression matrix and indicator matrix...
# End processing ready for DL...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 48it [00:07,  6.27it/s]
# initial_loss 1156.9238611857097
# Check if GPU is being used
# PASS! GPU is used for training!
# Training Network
# ...

# %%
# !python script_unrolled_dl.py --conventional --laplacian_genes --lambda_L_genes_reg 5000
# running
# Out:
# Constructing pytorch model...
# cuda:0
#  conventional
# conventional_processed_exp.npy
# conventional_processed_logmeanexp.npy
# GSM6858447_KO_conventional_perturbations.txt
# number of epochs 150
# lasso update period 20
# cuda:0
# processing conventional...
# Loading expression matrix and indicator matrix...
# End processing ready for DL...
# Initializing pytorch model...
# Initializing optimizer...
# Initializing loss function in model...
# Setting device...
# Setting Scheduler...
# Getting Initial loss...
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 249it [00:43,  5.74it/s]
# initial_loss 1393.9048341804719
# Check if GPU is being used
# PASS! GPU is used for training!
# Training Network
# ...

# %%
# !python script_unrolled_dl.py --conventional
# !python script_unrolled_dl.py --guide_pool
